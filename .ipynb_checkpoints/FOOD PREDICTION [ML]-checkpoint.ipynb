# %%
# Importing dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# fpn = Food Price Nigeria

# %%
fpn = pd.read_csv("wfp_food_prices_nga.csv", skiprows=[1])
fpn
# Out:
#              date   admin1    admin2       market   latitude  longitude  \
# 0      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 1      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 2      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 3      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 4      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# ...           ...      ...       ...          ...        ...        ...
# 73685  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73686  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73687  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73688  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73689  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
#
#                     category        commodity    unit  priceflag  pricetype  \
# 0         cereals and tubers            Maize      KG     actual  Wholesale
# 1         cereals and tubers           Millet      KG     actual  Wholesale
# 2         cereals and tubers  Rice (imported)      KG     actual  Wholesale
# 3         cereals and tubers          Sorghum      KG     actual  Wholesale
# 4            pulses and nuts    Beans (niebe)      KG     actual  Wholesale
# ...                      ...              ...     ...        ...        ...
# 73685  vegetables and fruits           Onions  0.5 KG  aggregate     Retail
# 73686  vegetables and fruits          Oranges   400 G  aggregate     Retail
# 73687  vegetables and fruits          Spinach   300 G  aggregate     Retail
# 73688  vegetables and fruits         Tomatoes  0.5 KG  aggregate     Retail
# 73689  vegetables and fruits      Watermelons  2.1 KG  aggregate     Retail
#
#       currency   price  usdprice
# 0          NGN  175.92    1.5525
# 1          NGN  150.18    1.3254
# 2          NGN  358.70    3.1656
# 3          NGN  155.61    1.3733
# 4          NGN  196.87    1.7374
# ...        ...     ...       ...
# 73685      NGN  200.00    0.2530
# 73686      NGN  200.00    0.2530
# 73687      NGN   50.00    0.0633
# 73688      NGN  200.00    0.2530
# 73689      NGN  400.00    0.5060
#
# [73690 rows x 14 columns]

# %%
fpn.describe()
# Out:
#            latitude     longitude          price      usdprice
# count  73690.000000  73690.000000   73690.000000  73690.000000
# mean      11.446065     10.490864    5424.801839     16.378580
# std        1.634753      2.915867   10971.943319     31.462483
# min        5.147640      3.401897       1.000000      0.002300
# 25%       11.280160      8.429120     200.000000      0.602000
# 50%       11.831100     11.499503     483.055000      1.324800
# 75%       12.362300     13.141492    3504.837500     16.389000
# max       13.645000     13.913103  138000.000000    456.922400

# %%
# Checks for NaN or null values and returns the column they were found in

columns_with_null = fpn.columns[fpn.isna().any()].tolist()

if len(columns_with_null) > 0:
    print("The following columns have NaN or null values:")
    print(columns_with_null)
else:
    print("No columns have NaN or null values.")
# Out:
# No columns have NaN or null values.

# %%
# Data Cleaning and Exploration

# %%
# Finding anomalies is in our data like wrong datatypes, inconsistent input, and wrong units

fpn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73690 entries, 0 to 73689
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       73690 non-null  object
#  1   admin1     73690 non-null  object
#  2   admin2     73690 non-null  object
#  3   market     73690 non-null  object
#  4   latitude   73690 non-null  float64
#  5   longitude  73690 non-null  float64
#  6   category   73690 non-null  object
#  7   commodity  73690 non-null  object
#  8   unit       73690 non-null  object
#  9   priceflag  73690 non-null  object
#  10  pricetype  73690 non-null  object
#  11  currency   73690 non-null  object
#  12  price      73690 non-null  float64
#  13  usdprice   73690 non-null  float64
# dtypes: float64(4), object(10)
# memory usage: 7.9+ MB

# %%
# Converting the date column fron object to datetime to enable time series analysis
fpn["date"] = pd.to_datetime(fpn["date"])

# %%
fpn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73690 entries, 0 to 73689
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       73690 non-null  datetime64[ns]
#  1   admin1     73690 non-null  object
#  2   admin2     73690 non-null  object
#  3   market     73690 non-null  object
#  4   latitude   73690 non-null  float64
#  5   longitude  73690 non-null  float64
#  6   category   73690 non-null  object
#  7   commodity  73690 non-null  object
#  8   unit       73690 non-null  object
#  9   priceflag  73690 non-null  object
#  10  pricetype  73690 non-null  object
#  11  currency   73690 non-null  object
#  12  price      73690 non-null  float64
#  13  usdprice   73690 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(9)
# memory usage: 7.9+ MB

# %%
# Defining a function to detect inconsistensies in certain columns that should and also find the distinct entries

def detect(col):
    unique = fpn[col].unique()
    print(f"{col} : {unique}")
    
cols_to_det = ["category", "commodity", "unit", "priceflag", "pricetype", "currency"]

# Iterating over the columns to detect inconsistencies and find distinct entries
for col in cols_to_det:
    detect(col)
# Out:
# category : ['cereals and tubers' 'pulses and nuts' 'non-food' 'oil and fats'
#  'meat, fish and eggs' 'milk and dairy' 'vegetables and fruits'
#  'miscellaneous food']
# commodity : ['Maize' 'Millet' 'Rice (imported)' 'Sorghum' 'Beans (niebe)' 'Wheat'
#  'Maize (white)' 'Sorghum (white)' 'Rice (milled, local)' 'Bread'
#  'Cassava meal (gari, yellow)' 'Gari (white)' 'Maize (yellow)'
#  'Rice (local)' 'Sorghum (brown)' 'Yam (Abuja)' 'Fuel (diesel)'
#  'Fuel (petrol-gasoline)' 'Oil (palm)' 'Cowpeas (brown)' 'Cowpeas (white)'
#  'Yam' 'Groundnuts (shelled)' 'Maize flour' 'Meat (beef)' 'Meat (goat)'
#  'Milk' 'Oil (vegetable)' 'Beans (red)' 'Beans (white)' 'Groundnuts'
#  'Onions' 'Fish' 'Eggs' 'Bananas' 'Oranges' 'Spinach' 'Watermelons'
#  'Cowpeas' 'Tomatoes' 'Salt' 'Sugar']
# unit : ['KG' '100 KG' '50 KG' 'Unit' 'L' '100 L' '1.3 KG' '1.4 KG' '3.4 KG'
#  '20 G' '750 ML' '1.1 KG' '0.5 KG' '1.5 KG' '30 pcs' '400 G' '300 G'
#  '2.1 KG' '3.1 KG' '1.2 KG' '250 G' '100 Tubers' '2.5 KG' '500 G']
# priceflag : ['actual' 'aggregate']
# pricetype : ['Wholesale' 'Retail']
# currency : ['NGN']

# %%
# From the output fpn table above, it seems like when the "priceflag" is "actual", the corresponding unit is "KG". This can be useful in standardizing all 
# values in our "unit" column to 1 KG or "KG" in relation to the price. This code is confirming this inference

# %%
fpn[fpn["priceflag"] == "actual"]["unit"].unique()
# Out:
# array(['KG', '100 KG', '50 KG', 'Unit', 'L', '100 L', '1.3 KG', '1.4 KG',
#        '3.4 KG', '20 G', '750 ML', '1.1 KG', '0.5 KG', '1.5 KG', '30 pcs',
#        '400 G', '300 G', '2.1 KG', '3.1 KG', '1.2 KG', '250 G',
#        '100 Tubers'], dtype=object)

# %%
fpn[fpn["priceflag"] == "aggregate"]["unit"].unique()
# Out:
# array(['2.5 KG', '30 pcs', 'KG', '20 G', '500 G', 'L', '1.3 KG', '0.5 KG',
#        '400 G', '300 G', '2.1 KG', 'Unit', '100 KG', '50 KG',
#        '100 Tubers', '1.2 KG'], dtype=object)

# %%
# From the outputs above, we see that there is no such pattern. So we can disregard the "priceflag" column.

# %%
# For consistency in units, we'd find out the commodities with irregular units to know if we can convert them to KG

# %%
fpn[fpn["unit"] == "30 pcs"]["commodity"].unique()
# Out:
# array(['Eggs'], dtype=object)

# %%
(fpn["unit"] == "30 pcs").sum()
# Out:
# 1442

# %%
fpn[fpn["unit"] == "Unit"]["commodity"].unique()
# Out:
# array(['Bread'], dtype=object)

# %%
(fpn["unit"] == "Unit").sum()
# Out:
# 1457

# %%
fpn[fpn["unit"] == "100 Tubers"]["commodity"].unique()
# Out:
# array(['Yam', 'Yam (Abuja)'], dtype=object)

# %%
(fpn["unit"] == "100 Tubers").sum()
# Out:
# 472

# %%
fpn[fpn["unit"].str.contains("L")]["commodity"].unique()
# Out:
# array(['Fuel (diesel)', 'Fuel (petrol-gasoline)', 'Oil (palm)',
#        'Oil (vegetable)'], dtype=object)

# %%
# So we've found out that where the units 30pcs - the corresponding commodity was eggs, where it was "Unit" -  "Bread"
# and where it was "100 Tubers" - ['Yam', 'Yam (Abuja)']. 


# We also found out commodities that were in litres because they are liquid. Two of these - ['Fuel (diesel)', 'Fuel (petrol-gasoline)'] aren't food
# commodities and we'd be dropping them later on.


# For uniformity in analysis, we'd be converting these commodities to their corresponding masses in KG. We're are referencing Google for the average weight
# of these commodities.

# %%
fpn.unit.unique()
# Out:
# array(['KG', '100 KG', '50 KG', 'Unit', 'L', '100 L', '1.3 KG', '1.4 KG',
#        '3.4 KG', '20 G', '750 ML', '1.1 KG', '0.5 KG', '1.5 KG', '30 pcs',
#        '400 G', '300 G', '2.1 KG', '3.1 KG', '1.2 KG', '250 G',
#        '100 Tubers', '2.5 KG', '500 G'], dtype=object)

# %%
fpn["itemtype"] = fpn["unit"].apply(lambda x: "Liquid" if "L" in x else "Solid")

# %%
fpn.sample(15)
# Out:
#             date   admin1        admin2             market   latitude  \
# 31764 2019-06-15     Yobe      Karasuwa      Bade (Gashua)  12.868665
# 64465 2022-09-15     Kano  Dawakin Tofa            Dawanau  12.090120
# 20446 2018-02-15     Yobe         Gujba  Gujba (Buni Yadi)  11.285202
# 45705 2021-09-15    Borno       Konduga          Baga Road  11.867950
# 20116 2018-02-15    Borno     Maiduguri      Kusawam Shanu  11.858887
# 55223 2020-11-15   Jigawa       Kaugama            Gujungu  12.362300
# 47266 2021-11-15     Yobe      Potiskum           Potiskum  11.707240
# 45033 2021-07-15     Yobe        Geidam             Geidam  12.890278
# 12062 2017-01-15      Oyo  Ibadan North             Ibadan   7.401960
# 63563 2022-07-15  Katsina       Dandume            Dandume  11.416670
# 5621  2015-07-15   Kaduna          Giwa               Giwa  11.280160
# 58521 2021-06-15    Lagos        Kosofe              Lagos   6.612164
# 35686 2019-11-15     Yobe        Gulani   Gulani (Tettaba)  10.813902
# 44784 2021-06-15     Yobe      Yunusari           Yunusari  13.149834
# 10885 2016-11-15   Kaduna          Lere           Saminaka  10.416500
#
#        longitude               category                    commodity    unit  \
# 31764  11.039624  vegetables and fruits                      Oranges   400 G
# 64465   8.429120     cereals and tubers  Cassava meal (gari, yellow)      KG
# 20446  11.999501  vegetables and fruits                      Spinach   300 G
# 45705  13.123314    meat, fish and eggs                         Fish  1.5 KG
# 20116  13.175996     cereals and tubers                          Yam  3.4 KG
# 55223   9.583600        pulses and nuts              Cowpeas (white)      KG
# 47266  11.082490     cereals and tubers                 Gari (white)      KG
# 45033  11.921166     cereals and tubers                       Millet  1.4 KG
# 12062   3.917310     cereals and tubers              Sorghum (brown)  100 KG
# 63563   7.200000     cereals and tubers                        Bread    Unit
# 5621    7.417860     cereals and tubers              Rice (imported)   50 KG
# 58521   3.401897        pulses and nuts         Groundnuts (shelled)      KG
# 35686  11.728192  vegetables and fruits                     Tomatoes  0.5 KG
# 44784  11.540236     cereals and tubers                  Maize flour  1.3 KG
# 10885   8.681380     cereals and tubers                        Bread    Unit
#
#        priceflag  pricetype currency     price  usdprice itemtype
# 31764     actual     Retail      NGN     60.00    0.1955    Solid
# 64465  aggregate     Retail      NGN    277.43    0.6485    Solid
# 20446     actual     Retail      NGN     50.00    0.1401    Solid
# 45705     actual     Retail      NGN    500.00    1.2165    Solid
# 20116     actual     Retail      NGN    425.00    1.1905    Solid
# 55223  aggregate     Retail      NGN    224.83    0.5901    Solid
# 47266     actual     Retail      NGN    412.50    1.0059    Solid
# 45033     actual     Retail      NGN    250.00    0.6090    Solid
# 12062     actual  Wholesale      NGN  15000.00   49.1608    Solid
# 63563  aggregate     Retail      NGN    332.26    0.8009    Solid
# 5621      actual  Wholesale      NGN   8704.00   43.7607    Solid
# 58521  aggregate     Retail      NGN    659.73    1.6013    Solid
# 35686     actual     Retail      NGN     70.00    0.1955    Solid
# 44784     actual     Retail      NGN    380.00    0.9223    Solid
# 10885     actual     Retail      NGN    245.09    0.7781    Solid

# %%
fpn[~fpn["unit"].str.contains(" ")]["unit"].unique()
# Out:
# array(['KG', 'Unit', 'L'], dtype=object)

# %%
# Standardizing the unit column with the price column so that the weight of all the commodities are unit KG and the prices are modified to be per kG of that commodity

# %%
def standardize_30pcs(df):
    for index, row in df.iterrows():
        unit = row['unit']
        if unit == "30 pcs":
            # On average, a medium-sized chicken egg weighs approximately 49.6 grams or 1.75 ounces. Now, let’s calculate the weight of 30 eggs:
            #Weight of one egg (medium): 49.6 grams
            #Weight of 30 eggs: (30 \times 49.6 , \text{grams} = 1488 , \text{grams})
            #Therefore, 30 medium-sized eggs weigh approximately 1488 grams or approximately 1.49 kilograms. That’s a lot of eggs!
            val, st = unit.split(" ")
            val = float(val)
            df.at[index, "unit"] = f"{round(float(val) * 0.0496, 2)} KG"

# %%
standardize_30pcs(fpn)
fpn.sample(20)
# Out:
#             date   admin1        admin2                    market   latitude  \
# 47287 2021-11-15     Yobe      Potiskum                  Potiskum  11.707240
# 54924 2020-10-15    Kebbi        Gwandu                    Gwandu  12.493820
# 44859 2021-07-15    Borno       Konduga                 Baga Road  11.867950
# 67658 2023-02-15    Borno          Mafa             Dikwa Central  12.036942
# 30031 2019-03-15  Zamfara  Kaura Namoda              Kaura Namoda  12.595190
# 39683 2020-07-15    Borno       Konduga              Abba Gamaram  11.858182
# 18574 2017-11-15  Zamfara  Kaura Namoda              Kaura Namoda  12.595190
# 1694  2012-02-15  Katsina      Mai'Adua           Mai Adoua (CBM)  13.180000
# 50270 2022-05-15     Yobe      Karasuwa             Bade (Gashua)  12.868665
# 73254 2023-12-15    Borno       Konduga                Bullunkutu  11.829812
# 6441  2015-10-15   Kaduna          Giwa                      Giwa  11.280160
# 31661 2019-06-15     Yobe        Geidam                    Geidam  12.890278
# 29411 2019-03-15    Borno     Maiduguri               Tashan Bama  11.810953
# 71625 2023-10-15  Adamawa      Madagali                  Madagali  10.889839
# 30168 2019-04-15    Borno       Konduga                Bullunkutu  11.829812
# 67849 2023-02-15     Yobe      Damaturu                Bayantasha  11.744341
# 32996 2019-08-15      Oyo  Ibadan North                    Ibadan   7.401960
# 50773 2023-03-15     Yobe        Gulani          Gulani (Tettaba)  10.813902
# 21770 2018-04-15     Yobe      Damaturu  Damaturu (Sunday Market)  11.739766
# 1391  2011-01-15   Jigawa     Maigatari          Mai Gatari (CBM)  12.780000
#
#        longitude               category               commodity     unit  \
# 47287  11.082490     cereals and tubers                     Yam   3.1 KG
# 54924   4.642270     cereals and tubers                     Yam       KG
# 44859  13.123314     cereals and tubers         Rice (imported)   1.4 KG
# 67658  13.913103        pulses and nuts                 Cowpeas   2.5 KG
# 30031   6.586350     cereals and tubers         Sorghum (brown)       KG
# 39683  13.154892    meat, fish and eggs                    Eggs  1.49 KG
# 18574   6.586350        pulses and nuts         Cowpeas (white)   100 KG
# 1694    8.230000     cereals and tubers                   Maize       KG
# 50270  11.039624           oil and fats              Oil (palm)   750 ML
# 73254  13.092646    meat, fish and eggs             Meat (goat)       KG
# 6441    7.417860               non-food  Fuel (petrol-gasoline)        L
# 31661  11.921166        pulses and nuts              Groundnuts   1.2 KG
# 29411  13.182150     miscellaneous food                   Sugar   1.3 KG
# 71625  13.627446     cereals and tubers             Maize flour   2.5 KG
# 30168  13.092646  vegetables and fruits                  Onions   0.5 KG
# 67849  11.962944           oil and fats              Oil (palm)        L
# 32996   3.917310        pulses and nuts         Cowpeas (white)   100 KG
# 50773  11.728192           oil and fats         Oil (vegetable)   750 ML
# 21770  11.955811    meat, fish and eggs             Meat (goat)       KG
# 1391    9.440000     cereals and tubers         Rice (imported)       KG
#
#        priceflag  pricetype currency     price  usdprice itemtype
# 47287     actual     Retail      NGN    375.00    0.9145    Solid
# 54924  aggregate     Retail      NGN    151.81    0.3990    Solid
# 44859     actual     Retail      NGN   1000.00    2.4361    Solid
# 67658  aggregate     Retail      NGN   1226.92    2.6669    Solid
# 30031     actual     Retail      NGN     84.06    0.2355    Solid
# 39683     actual     Retail      NGN   1015.00    2.6261    Solid
# 18574     actual  Wholesale      NGN  21300.00   59.8315    Solid
# 1694      actual  Wholesale      NGN    173.14    1.0876    Solid
# 50270     actual     Retail      NGN    933.00    2.2430   Liquid
# 73254  aggregate     Retail      NGN   3500.00    4.4276    Solid
# 6441      actual     Retail      NGN     87.00    0.4373   Liquid
# 31661     actual     Retail      NGN    325.00    1.0589    Solid
# 29411     actual     Retail      NGN    550.00    1.5406    Solid
# 71625  aggregate     Retail      NGN   1116.13    1.4509    Solid
# 30168     actual     Retail      NGN    150.00    0.4172    Solid
# 67849  aggregate     Retail      NGN   1257.14    2.7326   Liquid
# 32996     actual  Wholesale      NGN  16200.00   44.6687    Solid
# 50773     actual     Retail      NGN    900.00    1.9564   Liquid
# 21770     actual     Retail      NGN   1100.00    3.5986    Solid
# 1391      actual  Wholesale      NGN    422.28    2.7922    Solid

# %%
def standardize_unit(df):
    for index, row in df.iterrows():
        unit = row['unit']
        if unit == "Unit":
            # A typical white or whole wheat bread loaf may weigh between 16-24 ounces (450-680 grams).
            # We'd assume the weight to be the average of these values - 20 ounces(567g/0.567KG)
            df.at[index, "unit"] = f"{0.567} KG"

# %%
standardize_unit(fpn)
fpn.sample(20)
# Out:
#             date   admin1        admin2                    market   latitude  \
# 39819 2020-07-15    Borno     Maiduguri             Kusawam Shanu  11.858887
# 27611 2019-01-15    Borno       Konduga                 Baga Road  11.867950
# 62084 2022-04-15   Kaduna          Giwa                      Giwa  11.280160
# 16673 2017-09-15    Borno     Maiduguri             Kusawam Shanu  11.858887
# 51061 2023-04-15     Yobe         Nguru                     Nguru  12.872965
# 69522 2023-06-15     Yobe       Jakusko                   Jakusko  12.201859
# 25999 2018-10-15     Yobe         Nguru                     Nguru  12.872965
# 17279 2017-10-15    Borno       Konduga                Bullunkutu  11.829812
# 44693 2021-06-15     Yobe       Jakusko                   Jakusko  12.201859
# 43512 2021-03-15     Yobe      Damaturu  Damaturu (Sunday Market)  11.739766
# 54950 2020-10-15    Lagos        Kosofe                     Lagos   6.612164
# 33663 2019-09-15    Gombe          Akko                     Gombe  10.283330
# 8522  2016-05-15     Yobe      Potiskum                  Potiskum  11.707240
# 9101  2016-07-15    Borno     Maiduguri                    Monday  11.834551
# 50522 2023-02-15     Yobe        Gulani          Gulani (Tettaba)  10.813902
# 6026  2015-08-15  Zamfara  Kaura Namoda              Kaura Namoda  12.595190
# 37029 2020-01-15    Kebbi        Gwandu                    Gwandu  12.493820
# 5878  2015-08-15   Kaduna          Giwa                      Giwa  11.280160
# 73478 2023-12-15     Yobe      Damaturu                Bayantasha  11.744341
# 51101 2023-04-15     Yobe      Yusufari                  Yusufari  13.062665
#
#        longitude               category             commodity      unit  \
# 39819  13.175996  vegetables and fruits              Tomatoes    0.5 KG
# 27611  13.123314    meat, fish and eggs           Meat (beef)        KG
# 62084   7.417860        pulses and nuts  Groundnuts (shelled)        KG
# 16673  13.175996           oil and fats            Oil (palm)    750 ML
# 51061  10.445595        pulses and nuts               Cowpeas    1.2 KG
# 69522  10.878244        pulses and nuts         Beans (white)    2.5 KG
# 25999  10.445595  vegetables and fruits               Spinach     300 G
# 17279  13.092646     cereals and tubers       Rice (imported)    1.4 KG
# 44693  10.878244    meat, fish and eggs           Meat (goat)        KG
# 43512  11.955811  vegetables and fruits               Bananas    1.3 KG
# 54950   3.401897     cereals and tubers       Sorghum (brown)        KG
# 33663  11.166670     cereals and tubers       Sorghum (brown)    100 KG
# 8522   11.082490           oil and fats            Oil (palm)         L
# 9101   13.152417    meat, fish and eggs                  Fish    1.5 KG
# 50522  11.728192     cereals and tubers           Maize flour    1.3 KG
# 6026    6.586350     cereals and tubers                 Bread  0.567 KG
# 37029   4.642270     cereals and tubers          Gari (white)    100 KG
# 5878    7.417860     cereals and tubers  Rice (milled, local)     50 KG
# 73478  11.962944     miscellaneous food                 Sugar     500 G
# 51101  11.171371           oil and fats       Oil (vegetable)    750 ML
#
#        priceflag  pricetype currency     price  usdprice itemtype
# 39819     actual     Retail      NGN     80.00    0.2070    Solid
# 27611     actual     Retail      NGN   1200.00    3.3012    Solid
# 62084  aggregate     Retail      NGN    673.40    1.6265    Solid
# 16673     actual     Retail      NGN    390.00    1.1143   Liquid
# 51061     actual     Retail      NGN    533.00    1.1573    Solid
# 69522  aggregate     Retail      NGN   1000.00    1.5385    Solid
# 25999     actual     Retail      NGN     50.00    0.1379    Solid
# 17279     actual     Retail      NGN    575.00    1.8805    Solid
# 44693     actual     Retail      NGN   1750.00    4.2476    Solid
# 43512     actual     Retail      NGN    200.00    0.5256    Solid
# 54950  aggregate     Retail      NGN    325.12    0.8544    Solid
# 33663     actual  Wholesale      NGN   7375.00   24.0228    Solid
# 8522      actual     Retail      NGN    279.66    1.4196   Liquid
# 9101      actual     Retail      NGN    100.00    0.3565    Solid
# 50522     actual     Retail      NGN    364.00    0.7912    Solid
# 6026      actual     Retail      NGN    210.52    1.0686    Solid
# 37029     actual  Wholesale      NGN   7475.00   20.7639    Solid
# 5878      actual  Wholesale      NGN  14000.00   71.0660    Solid
# 73478  aggregate     Retail      NGN    800.00    1.0120    Solid
# 51101     actual     Retail      NGN    750.00    1.6285   Liquid

# %%
def standardize_100tubers(df):
    for index, row in df.iterrows():
        unit = row['unit']
        if unit == "100 Tubers":
            # In terms of weight, cultivated yam tubers can vary significantly, but on average, they weigh between 5 to 10 kilograms. 
            # Let’s consider the lower end of this range for our calculation.
            # Assuming we take a conservative estimate of 5 kilograms per yam tuber, we can determine how many tubers would amount to 1 kilogram:
            val, st = unit.split(" ")
            val = float(val)
            df.at[index, "unit"] = f"{round(float(val) * 5, 2)} KG"

# %%
standardize_100tubers(fpn)
fpn.sample(20)
# Out:
#             date  admin1        admin2            market   latitude  \
# 362   2005-02-15  Sokoto          Gada      Illela (CBM)  13.645000
# 30256 2019-04-15   Borno     Maiduguri         Maiduguri  11.831100
# 70086 2023-07-15   Borno     Maiduguri       Tashan Bama  11.810953
# 65254 2022-11-15   Borno       Konduga              Bama  11.522899
# 17514 2017-10-15   Kebbi        Gwandu            Gwandu  12.493820
# 26670 2018-11-15    Yobe       Jakusko           Jakusko  12.201859
# 71969 2023-10-15   Borno     Maiduguri             Budum  11.849734
# 71381 2023-09-15   Borno     Maiduguri    Kashuwan Shanu  11.858656
# 32388 2019-07-15    Yobe         Nguru             Nguru  12.872965
# 11554 2016-12-15    Yobe      Karasuwa     Bade (Gashua)  12.868665
# 1412  2011-02-15  Jigawa     Maigatari  Mai Gatari (CBM)  12.780000
# 22734 2018-05-15    Yobe      Yusufari          Yusufari  13.062665
# 44097 2021-05-15   Borno     Maiduguri            Monday  11.834551
# 42451 2021-01-15   Borno     Maiduguri            Custom  11.850710
# 36907 2020-01-15  Jigawa       Kaugama           Gujungu  12.362300
# 26225 2018-11-15   Borno     Maiduguri             Budum  11.849734
# 17334 2017-10-15   Borno     Maiduguri            Custom  11.850710
# 55391 2020-11-15   Lagos        Kosofe             Lagos   6.612164
# 42943 2021-02-15   Borno     Maiduguri     Kusawam Shanu  11.858887
# 8884  2016-06-15     Oyo  Ibadan North            Ibadan   7.401960
#
#        longitude               category               commodity      unit  \
# 362     5.278000     cereals and tubers                  Millet        KG
# 30256  13.150970     cereals and tubers                  Millet        KG
# 70086  13.182150         milk and dairy                    Milk      20 G
# 65254  13.689198     miscellaneous food                    Salt     500 G
# 17514   4.642270     cereals and tubers                   Bread  0.567 KG
# 26670  10.878244  vegetables and fruits             Watermelons    2.1 KG
# 71969  13.163442  vegetables and fruits                 Bananas    1.3 KG
# 71381  13.178033    meat, fish and eggs                    Eggs   1.49 KG
# 32388  10.445595    meat, fish and eggs             Meat (beef)        KG
# 11554  11.039624  vegetables and fruits                Tomatoes    0.5 KG
# 1412    9.440000     cereals and tubers                   Maize        KG
# 22734  11.171371  vegetables and fruits                 Oranges     400 G
# 44097  13.152417    meat, fish and eggs                    Fish    1.5 KG
# 42451  13.171242    meat, fish and eggs                    Fish    1.5 KG
# 36907   9.583600               non-food  Fuel (petrol-gasoline)         L
# 26225  13.163442    meat, fish and eggs             Meat (beef)        KG
# 17334  13.171242     miscellaneous food                    Salt     250 G
# 55391   3.401897        pulses and nuts         Cowpeas (brown)    100 KG
# 42943  13.175996        pulses and nuts             Beans (red)    1.3 KG
# 8884    3.917310        pulses and nuts         Cowpeas (brown)    100 KG
#
#        priceflag  pricetype currency     price  usdprice itemtype
# 362       actual  Wholesale      NGN    150.84    1.1834    Solid
# 30256     actual     Retail      NGN    107.69    0.2996    Solid
# 70086  aggregate     Retail      NGN   1568.18    2.0508    Solid
# 65254  aggregate     Retail      NGN    500.00    1.1342    Solid
# 17514     actual     Retail      NGN    397.00    1.2983    Solid
# 26670     actual     Retail      NGN    200.00    0.5495    Solid
# 71969  aggregate     Retail      NGN    304.03    0.3952    Solid
# 71381  aggregate     Retail      NGN    100.00    0.1276    Solid
# 32388     actual     Retail      NGN    900.00    2.5035    Solid
# 11554     actual     Retail      NGN     50.00    0.1587    Solid
# 1412      actual  Wholesale      NGN    183.87    1.2065    Solid
# 22734     actual     Retail      NGN     50.00    0.1389    Solid
# 44097     actual     Retail      NGN    613.00    1.5503    Solid
# 42451     actual     Retail      NGN    993.00    2.6480    Solid
# 36907     actual     Retail      NGN    144.40    0.4011   Liquid
# 26225     actual     Retail      NGN   1150.00    3.1593    Solid
# 17334     actual     Retail      NGN     65.00    0.2126    Solid
# 55391  aggregate  Wholesale      NGN  32020.00   84.0420    Solid
# 42943     actual     Retail      NGN    389.00    1.0219    Solid
# 8884      actual  Wholesale      NGN  23560.00  118.4515    Solid

# %%
def standardize_KG_G(df):
    for index, row in df.iterrows():
        unit = row['unit']
        if unit == "KG":
            df.at[index, "unit"] = "1 KG"
        elif " " in unit:
            val, st = unit.split(" ")
            if st == "KG":
                df.at[index, "unit"] = unit
            elif st == "G":
                df.at[index, "unit"] = f"{round(float(val) / 1000, 2)} KG"

# %%
standardize_KG_G(fpn)
fpn.sample(20)
# Out:
#             date  admin1        admin2             market   latitude  \
# 44564 2021-06-15    Yobe       Borsari            Bursari  12.496693
# 25679 2018-10-15  Kaduna          Giwa               Giwa  11.280160
# 22386 2018-05-15   Kebbi        Gwandu             Gwandu  12.493820
# 6582  2015-10-15    Yobe      Potiskum           Potiskum  11.707240
# 880   2008-11-15    Kano  Dawakin Tofa            Dawanau  12.090120
# 13820 2017-04-15    Yobe       Jakusko            Jakusko  12.201859
# 70664 2023-08-15   Borno          Mafa      Dikwa Central  12.036942
# 32164 2019-07-15   Kebbi        Gwandu             Gwandu  12.493820
# 19046 2017-12-15    Yobe         Gujba  Gujba (Buni Yadi)  11.285202
# 43862 2021-04-15   Borno     Maiduguri             Custom  11.850710
# 4358  2015-02-15    Kano  Dawakin Tofa            Dawanau  12.090120
# 56687 2021-02-15     Oyo  Ibadan North             Ibadan   7.401960
# 66874 2023-01-15  Kaduna          Lere           Saminaka  10.416500
# 25631 2018-10-15   Borno     Maiduguri        Tashan Bama  11.810953
# 60315 2021-10-15   Kebbi        Gwandu             Gwandu  12.493820
# 18368 2017-11-15    Yobe         Gujba  Gujba (Buni Yadi)  11.285202
# 60392 2021-10-15     Oyo  Ibadan North             Ibadan   7.401960
# 51187 2023-05-15   Borno     Maiduguri             Monday  11.834551
# 8346  2016-05-15   Gombe          Akko              Gombe  10.283330
# 70317 2023-07-15    Yobe      Potiskum           Potiskum  11.707240
#
#        longitude               category               commodity    unit  \
# 44564  11.499503     cereals and tubers            Rice (local)  1.4 KG
# 25679   7.417860               non-food  Fuel (petrol-gasoline)       L
# 22386   4.642270     cereals and tubers                  Millet  100 KG
# 6582   11.082490           oil and fats              Oil (palm)       L
# 880     8.429120     cereals and tubers           Maize (white)  100 KG
# 13820  10.878244        pulses and nuts           Beans (white)  1.2 KG
# 70664  13.913103           oil and fats              Oil (palm)       L
# 32164   4.642270               non-food  Fuel (petrol-gasoline)       L
# 19046  11.999501        pulses and nuts              Groundnuts  1.2 KG
# 43862  13.171242  vegetables and fruits                 Spinach  0.3 KG
# 4358    8.429120        pulses and nuts    Groundnuts (shelled)  100 KG
# 56687   3.917310        pulses and nuts         Cowpeas (brown)    1 KG
# 66874   8.681380     cereals and tubers         Sorghum (brown)    1 KG
# 25631  13.182150  vegetables and fruits                  Onions  0.5 KG
# 60315   4.642270     cereals and tubers            Gari (white)  100 KG
# 18368  11.999501  vegetables and fruits                Tomatoes  0.5 KG
# 60392   3.917310           oil and fats              Oil (palm)       L
# 51187  13.152417     miscellaneous food                   Sugar  1.3 KG
# 8346   11.166670               non-food           Fuel (diesel)       L
# 70317  11.082490        pulses and nuts           Beans (white)  2.5 KG
#
#        priceflag  pricetype currency     price  usdprice itemtype
# 44564     actual     Retail      NGN    500.00    1.2136    Solid
# 25679     actual     Retail      NGN    145.00    0.4000   Liquid
# 22386     actual  Wholesale      NGN  14260.00   39.6111    Solid
# 6582      actual     Retail      NGN    267.16    1.3428   Liquid
# 880       actual  Wholesale      NGN   4500.00   38.2117    Solid
# 13820     actual     Retail      NGN    350.00    1.1434    Solid
# 70664  aggregate     Retail      NGN   1266.67    1.6538   Liquid
# 32164     actual     Retail      NGN    145.00    0.4033   Liquid
# 19046     actual     Retail      NGN    600.00    1.6760    Solid
# 43862     actual     Retail      NGN     50.00    0.1316    Solid
# 4358      actual  Wholesale      NGN  16630.00   98.0080    Solid
# 56687  aggregate     Retail      NGN    497.61    1.3073    Solid
# 66874  aggregate     Retail      NGN    215.38    0.4675    Solid
# 25631     actual     Retail      NGN    100.00    0.2759    Solid
# 60315  aggregate  Wholesale      NGN  20174.84   49.1650    Solid
# 18368     actual     Retail      NGN     50.00    0.1404    Solid
# 60392  aggregate     Retail      NGN    921.72    2.2462   Liquid
# 51187     actual     Retail      NGN   1144.00    2.4868    Solid
# 8346      actual     Retail      NGN    131.25    0.6662   Liquid
# 70317  aggregate     Retail      NGN   1169.57    1.5295    Solid

# %%
def standardize_L_ML(df):
    for index, row in df.iterrows():
        unit = row['unit']
        commodity = row["commodity"]
        if "L" in unit:
            if unit == "L":
                if commodity == "Oil (palm)":
                    # 1 liter of palm oil weighs approximately 912.98 grams or 0.91 kilograms
                    # Please note that this estimation is based on the density of palm oil and serves as a good comparison.
                    df.at[index, "unit"] = "0.91 KG"
                elif commodity == "Oil (vegetable)":
                    # The density of vegetable oil varies depending on the type of oil. 
                    # On average, 1 kg of oil equals 1.09 liters. Therefore, 1 liter of vegetable oil weighs approximately 0.92 kg.
                    df.at[index, "unit"] = "0.92 KG"
                else:
                    pass
            else:
                if " " in unit:
                    val, st = unit.split(" ")
                    if st == "L":
                        if commodity == "Oil (palm)":
                            df.at[index, "unit"] = f"{round((float(val) * 0.91))} KG"
                        elif commodity == "Oil (vegetable)":
                            df.at[index, "unit"] = f"{round((float(val) * 0.92))} KG"
                    elif st == "ML":
                        if commodity == "Oil (palm)":
                            df.at[index, "unit"] = f"{round((float(val) / 1000) * 0.91)} KG"
                        elif commodity == "Oil (vegetable)":
                            df.at[index, "unit"] = f"{round((float(val) / 1000) * 0.92)} KG"

# %%
standardize_L_ML(fpn)
fpn.sample(20)
# Out:
#             date   admin1        admin2            market   latitude  \
# 20968 2018-03-15  Katsina       Dandume           Dandume  11.416670
# 68721 2023-05-15    Borno     Maiduguri            Custom  11.850710
# 29235 2019-03-15    Borno       Konduga         Baga Road  11.867950
# 65578 2022-11-15     Yobe      Damaturu          Damaturu  11.744440
# 7524  2016-02-15   Jigawa       Kaugama           Gujungu  12.362300
# 73287 2023-12-15    Borno          Mafa     Dikwa Central  12.036942
# 33707 2019-09-15   Kaduna          Giwa              Giwa  11.280160
# 54554 2020-09-15      Oyo  Ibadan North            Ibadan   7.401960
# 54709 2020-10-15    Borno     Maiduguri         Maiduguri  11.831100
# 32174 2019-07-15      Oyo  Ibadan North            Ibadan   7.401960
# 10282 2016-10-15    Borno     Maiduguri             Budum  11.849734
# 41725 2020-11-15     Yobe        Gulani  Gulani (Tettaba)  10.813902
# 70498 2023-08-15    Borno         Gwoza     Gwoza Central  11.087249
# 62804 2022-05-15  Zamfara  Kaura Namoda      Kaura Namoda  12.595190
# 19624 2018-01-15      Oyo  Ibadan North            Ibadan   7.401960
# 73306 2023-12-15    Borno     Maiduguri             Budum  11.849734
# 9982  2016-09-15   Jigawa       Kaugama           Gujungu  12.362300
# 61328 2022-02-15     Yobe      Damaturu          Damaturu  11.744440
# 41477 2020-11-15    Borno       Konduga        Bullunkutu  11.829812
# 24142 2018-08-15    Borno     Maiduguri         Maiduguri  11.831100
#
#        longitude               category        commodity      unit  priceflag  \
# 20968   7.200000     cereals and tubers              Yam      1 KG     actual
# 68721  13.171242        pulses and nuts    Beans (white)    2.5 KG  aggregate
# 29235  13.123314         milk and dairy             Milk   0.02 KG     actual
# 65578  11.961110        pulses and nuts  Cowpeas (brown)      1 KG  aggregate
# 7524    9.583600     cereals and tubers            Bread  0.567 KG     actual
# 73287  13.913103        pulses and nuts          Cowpeas    2.5 KG  aggregate
# 33707   7.417860     cereals and tubers   Maize (yellow)    100 KG     actual
# 54554   3.917310        pulses and nuts  Cowpeas (brown)      1 KG  aggregate
# 54709  13.150970     cereals and tubers     Gari (white)    100 KG  aggregate
# 32174   3.917310     cereals and tubers            Bread  0.567 KG     actual
# 10282  13.163442           oil and fats       Oil (palm)      1 KG     actual
# 41725  11.728192    meat, fish and eggs      Meat (goat)      1 KG     actual
# 70498  13.699824  vegetables and fruits          Spinach    0.3 KG  aggregate
# 62804   6.586350               non-food    Fuel (diesel)         L  aggregate
# 19624   3.917310     cereals and tubers  Sorghum (brown)      1 KG     actual
# 73306  13.163442     miscellaneous food             Salt    0.5 KG  aggregate
# 9982    9.583600     cereals and tubers     Gari (white)    100 KG     actual
# 61328  11.961110     cereals and tubers            Bread  0.567 KG  aggregate
# 41477  13.092646     cereals and tubers           Millet    1.4 KG     actual
# 24142  13.150970     cereals and tubers     Rice (local)    100 KG     actual
#
#        pricetype currency     price  usdprice itemtype
# 20968     Retail      NGN    266.30    0.7460    Solid
# 68721     Retail      NGN   1054.84    2.2930    Solid
# 29235     Retail      NGN     50.00    0.1401    Solid
# 65578     Retail      NGN    384.62    0.8725    Solid
# 7524      Retail      NGN    217.39    1.1037    Solid
# 73287     Retail      NGN   1304.96    1.6508    Solid
# 33707  Wholesale      NGN   8875.00   28.9088    Solid
# 54554     Retail      NGN    373.13    0.9924    Solid
# 54709  Wholesale      NGN  17903.23   47.0518    Solid
# 32174     Retail      NGN    341.30    0.9494    Solid
# 10282     Retail      NGN    358.60    1.1752   Liquid
# 41725     Retail      NGN   1000.00    2.6247    Solid
# 70498     Retail      NGN    112.50    0.1469    Solid
# 62804     Retail      NGN    663.35    1.5947   Liquid
# 19624     Retail      NGN    172.88    0.4829    Solid
# 73306     Retail      NGN    150.00    0.1898    Solid
# 9982   Wholesale      NGN   8250.00   26.4042    Solid
# 61328     Retail      NGN    224.00    0.5394    Solid
# 41477     Retail      NGN    227.00    0.5958    Solid
# 24142  Wholesale      NGN  27260.00   75.7222    Solid

# %%
fpn[~fpn["unit"].str.contains("KG")]["commodity"].unique()
# Out:
# array(['Fuel (diesel)', 'Fuel (petrol-gasoline)'], dtype=object)

# %%
# We've successfully standardized prices excluding non-food commodities['Fuel (diesel)', 'Fuel (petrol-gasoline)']

# %%
def standardize_price(df):
    for index, row in df.iterrows():
        unit = row['unit']
        price = row["price"]
        if "KG" in unit:
            if " " in unit:
                val, ut = unit.split(" ")
                val = float(val)
                df.at[index, "price"] = price / val
                df.at[index, "unit"] = "KG"
            else:
                df.at[index, "price"] = price  # No conversion needed

# %%
standardize_price(fpn)
fpn.sample(20)
# Out:
#             date   admin1        admin2            market   latitude  \
# 21858 2018-04-15     Yobe        Gulani  Gulani (Tettaba)  10.813902
# 40947 2020-09-15     Yobe      Yusufari          Yusufari  13.062665
# 56395 2021-02-15    Borno           Biu               Biu  10.611100
# 58891 2021-07-15     Kano  Dawakin Tofa           Dawanau  12.090120
# 39894 2020-07-15     Yobe        Geidam            Geidam  12.890278
# 29448 2019-03-15    Gombe          Akko             Gombe  10.283330
# 20253 2018-02-15     Kano  Dawakin Tofa           Dawanau  12.090120
# 13190 2017-03-15     Yobe       Jakusko           Jakusko  12.201859
# 35141 2019-10-15  Zamfara  Kaura Namoda      Kaura Namoda  12.595190
# 38838 2020-05-15    Borno     Maiduguri             Budum  11.849734
# 51773 2019-05-15   Jigawa       Kaugama           Gujungu  12.362300
# 24723 2018-09-15    Borno       Konduga      Abba Gamaram  11.858182
# 34515 2019-10-15    Borno     Maiduguri       Tashan Bama  11.810953
# 2373  2013-12-15   Kaduna          Giwa              Giwa  11.280160
# 35084 2019-10-15     Yobe      Yunusari          Yunusari  13.149834
# 41387 2020-10-15     Yobe      Yunusari          Yunusari  13.149834
# 37819 2020-02-15   Kaduna          Giwa              Giwa  11.280160
# 629   2007-01-15   Sokoto          Gada      Illela (CBM)  13.645000
# 51967 2020-03-15   Jigawa       Kaugama           Gujungu  12.362300
# 59158 2021-08-15  Adamawa          Hong              Mubi  10.267610
#
#        longitude               category               commodity unit  \
# 21858  11.728192  vegetables and fruits                 Spinach   KG
# 40947  11.171371     miscellaneous food                    Salt   KG
# 56395  12.195000               non-food  Fuel (petrol-gasoline)    L
# 58891   8.429120               non-food           Fuel (diesel)    L
# 39894  11.921166     cereals and tubers                  Millet   KG
# 29448  11.166670        pulses and nuts         Cowpeas (white)   KG
# 20253   8.429120     cereals and tubers         Rice (imported)   KG
# 13190  10.878244        pulses and nuts                 Cowpeas   KG
# 35141   6.586350        pulses and nuts         Cowpeas (white)   KG
# 38838  13.163442    meat, fish and eggs             Meat (goat)   KG
# 51773   9.583600     cereals and tubers         Sorghum (brown)   KG
# 24723  13.154892     miscellaneous food                    Salt   KG
# 34515  13.182150  vegetables and fruits                 Oranges   KG
# 2373    7.417860     cereals and tubers         Sorghum (white)   KG
# 35084  11.540236  vegetables and fruits                 Oranges   KG
# 41387  11.540236    meat, fish and eggs             Meat (goat)   KG
# 37819   7.417860     cereals and tubers         Sorghum (white)   KG
# 629     5.278000     cereals and tubers                 Sorghum   KG
# 51967   9.583600        pulses and nuts         Cowpeas (white)   KG
# 59158  13.264360               non-food  Fuel (petrol-gasoline)    L
#
#        priceflag  pricetype currency        price  usdprice itemtype
# 21858     actual     Retail      NGN   166.666667    0.1636    Solid
# 40947     actual     Retail      NGN   800.000000    0.5319    Solid
# 56395  aggregate     Retail      NGN   167.000000    0.4387   Liquid
# 58891  aggregate     Retail      NGN   188.000000    0.4580   Liquid
# 39894     actual     Retail      NGN   178.571429    0.6468    Solid
# 29448     actual  Wholesale      NGN   180.000000   50.4202    Solid
# 20253     actual  Wholesale      NGN   298.500000   41.8067    Solid
# 13190     actual     Retail      NGN   229.166667    0.8758    Solid
# 35141     actual     Retail      NGN   160.030000    0.4470    Solid
# 38838     actual     Retail      NGN  1140.000000    2.9457    Solid
# 51773  aggregate     Retail      NGN    69.230000    0.1926    Solid
# 24723     actual     Retail      NGN   560.000000    0.4571    Solid
# 34515     actual     Retail      NGN   250.000000    0.2793    Solid
# 2373      actual  Wholesale      NGN    52.000000   33.0641    Solid
# 35084     actual     Retail      NGN   175.000000    0.1955    Solid
# 41387     actual     Retail      NGN  1200.000000    3.1537    Solid
# 37819     actual     Retail      NGN    92.590000    0.3016    Solid
# 629       actual  Wholesale      NGN    96.510000    0.7870    Solid
# 51967  aggregate     Retail      NGN   141.180000    0.4238    Solid
# 59158  aggregate     Retail      NGN   165.250000    0.4028   Liquid

# %%
fpn.sample(20)
# Out:
#             date   admin1        admin2                    market   latitude  \
# 1398  2011-01-15  Katsina         Jibia               Jibia (CBM)  13.080000
# 71456 2023-09-15    Borno        Mobbar           Damassack (CBM)  13.010000
# 42510 2021-01-15    Borno     Maiduguri                    Monday  11.834551
# 7204  2016-01-15    Borno           Biu                       Biu  10.611100
# 48333 2022-01-15    Borno     Maiduguri                     Budum  11.849734
# 54102 2020-08-15      Oyo  Ibadan North                    Ibadan   7.401960
# 19220 2017-12-15     Yobe      Yusufari                  Yusufari  13.062665
# 6832  2015-11-15     Yobe      Damaturu                  Damaturu  11.744440
# 16305 2017-08-15     Yobe      Damaturu                  Damaturu  11.744440
# 44590 2021-06-15     Yobe      Damaturu  Damaturu (Sunday Market)  11.739766
# 42476 2021-01-15    Borno     Maiduguri             Kusawam Shanu  11.858887
# 9897  2016-09-15    Borno     Maiduguri             Kusawam Shanu  11.858887
# 47040 2021-11-15     Yobe       Borsari                   Bursari  12.496693
# 47497 2021-12-15    Borno       Konduga              Abba Gamaram  11.858182
# 28581 2019-02-15   Kaduna          Giwa                      Giwa  11.280160
# 57876 2021-05-15   Jigawa       Kaugama                   Gujungu  12.362300
# 38225 2020-02-15     Yobe         Nguru                     Nguru  12.872965
# 21463 2018-04-15    Borno     Maiduguri                     Budum  11.849734
# 9058  2016-07-15    Borno     Maiduguri                    Custom  11.850710
# 5699  2015-07-15    Kebbi        Gwandu                    Gwandu  12.493820
#
#        longitude               category        commodity unit  priceflag  \
# 1398    7.240000     cereals and tubers  Rice (imported)   KG     actual
# 71456  12.560000    meat, fish and eggs             Eggs   KG  aggregate
# 42510  13.152417        pulses and nuts       Groundnuts   KG     actual
# 7204   12.195000        pulses and nuts  Cowpeas (white)   KG     actual
# 48333  13.163442    meat, fish and eggs             Eggs   KG     actual
# 54102   3.917310     cereals and tubers   Maize (yellow)   KG  aggregate
# 19220  11.171371     cereals and tubers     Rice (local)   KG     actual
# 6832   11.961110     cereals and tubers  Sorghum (brown)   KG     actual
# 16305  11.961110           oil and fats       Oil (palm)   KG     actual
# 44590  11.955811     cereals and tubers          Sorghum   KG     actual
# 42476  13.175996    meat, fish and eggs      Meat (beef)   KG     actual
# 9897   13.175996           oil and fats       Oil (palm)   KG     actual
# 47040  11.499503     cereals and tubers              Yam   KG     actual
# 47497  13.154892           oil and fats  Oil (vegetable)   KG     actual
# 28581   7.417860     cereals and tubers     Gari (white)   KG     actual
# 57876   9.583600     cereals and tubers  Sorghum (white)   KG  aggregate
# 38225  10.445595  vegetables and fruits      Watermelons   KG     actual
# 21463  13.163442     miscellaneous food             Salt   KG     actual
# 9058   13.171242        pulses and nuts      Beans (red)   KG     actual
# 5699    4.642270     cereals and tubers  Sorghum (brown)   KG     actual
#
#        pricetype currency        price  usdprice itemtype
# 1398   Wholesale      NGN   468.910000    3.1005    Solid
# 71456     Retail      NGN  1610.738255    3.0612    Solid
# 42510     Retail      NGN   400.000000    1.1733    Solid
# 7204   Wholesale      NGN   112.250000   57.3113    Solid
# 48333     Retail      NGN  1208.053691    4.2466    Solid
# 54102  Wholesale      NGN   206.838700   54.2884    Solid
# 19220     Retail      NGN   428.571429    1.6760    Solid
# 6832   Wholesale      NGN    48.000000   24.3655    Solid
# 16305     Retail      NGN   591.208791    1.4740   Liquid
# 44590     Retail      NGN   211.538462    0.6675    Solid
# 42476     Retail      NGN  1243.000000    3.3147    Solid
# 9897      Retail      NGN   350.000000    1.1202   Liquid
# 47040     Retail      NGN   422.903226    3.1969    Solid
# 47497     Retail      NGN   700.000000    1.7095   Liquid
# 28581     Retail      NGN   176.620000    0.4920    Solid
# 57876     Retail      NGN   172.410000    0.4360    Solid
# 38225     Retail      NGN    59.523810    0.4072    Solid
# 21463     Retail      NGN   220.000000    0.1799    Solid
# 9058      Retail      NGN   223.076923    1.0340    Solid
# 5699   Wholesale      NGN    57.120000   28.7179    Solid

# %%
# We've successfully standardized units and prices. We'd now filter out columns that we'd not be using as features and non-food rows

# %%
# Dropping non-food rows

# %%
fpn = fpn[fpn["category"] != "non-food"]

# %%
# Confirming that the "non-food rows havebeen dropped"

# %%
fpn[fpn["category"] == "non-food"]
# Out:
# Empty DataFrame
# Columns: [date, admin1, admin2, market, latitude, longitude, category, commodity, unit, priceflag, pricetype, currency, price, usdprice, itemtype]
# Index: []

# %%
# Dropping columns

# %%
fpn.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'unit', 'priceflag', 'pricetype', 'currency',
#        'price', 'usdprice', 'itemtype'],
#       dtype='object')

# %%
cols_to_drop = ["unit", "priceflag", "pricetype", "currency", "usdprice"]
fpn = fpn.drop(cols_to_drop, axis=1)

# %%
fpn
# Out:
#             date   admin1    admin2       market   latitude  longitude  \
# 0     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 1     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 2     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 3     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 4     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# ...          ...      ...       ...          ...        ...        ...
# 73685 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73686 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73687 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73688 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73689 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
#
#                     category        commodity       price itemtype
# 0         cereals and tubers            Maize  175.920000    Solid
# 1         cereals and tubers           Millet  150.180000    Solid
# 2         cereals and tubers  Rice (imported)  358.700000    Solid
# 3         cereals and tubers          Sorghum  155.610000    Solid
# 4            pulses and nuts    Beans (niebe)  196.870000    Solid
# ...                      ...              ...         ...      ...
# 73685  vegetables and fruits           Onions  400.000000    Solid
# 73686  vegetables and fruits          Oranges  500.000000    Solid
# 73687  vegetables and fruits          Spinach  166.666667    Solid
# 73688  vegetables and fruits         Tomatoes  400.000000    Solid
# 73689  vegetables and fruits      Watermelons  190.476190    Solid
#
# [73690 rows x 10 columns]

# %%
# Lag

# %%
fpn
# Out:
#             date   admin1    admin2       market   latitude  longitude  \
# 0     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 1     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 2     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 3     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 4     2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# ...          ...      ...       ...          ...        ...        ...
# 73685 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73686 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73687 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73688 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73689 2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
#
#                     category        commodity       price itemtype
# 0         cereals and tubers            Maize  175.920000    Solid
# 1         cereals and tubers           Millet  150.180000    Solid
# 2         cereals and tubers  Rice (imported)  358.700000    Solid
# 3         cereals and tubers          Sorghum  155.610000    Solid
# 4            pulses and nuts    Beans (niebe)  196.870000    Solid
# ...                      ...              ...         ...      ...
# 73685  vegetables and fruits           Onions  400.000000    Solid
# 73686  vegetables and fruits          Oranges  500.000000    Solid
# 73687  vegetables and fruits          Spinach  166.666667    Solid
# 73688  vegetables and fruits         Tomatoes  400.000000    Solid
# 73689  vegetables and fruits      Watermelons  190.476190    Solid
#
# [70824 rows x 10 columns]

# %%
# Store the original order of the DataFrame
original_order = fpn.index


# Sort the DataFrame by 'commodity' and 'date' columns
df_sorted = fpn.sort_values(by=['commodity', 'date'])

# Define lag periods
lag_periods = [3, 6, 9, 12,18, 24]  # in months

# Function to apply lag operation within each commodity group
def lag_prices(group):
    for lag in lag_periods:
        group[f'{lag}m_lag_price'] = group['price'].shift(periods=lag)
    return group


# Apply the lag operation within each commodity group
df_sorted = df_sorted.groupby('commodity').apply(lag_prices)

# Restore the original order of the DataFrame
fpn = df_sorted.loc[original_order]

# %%
# Import necessary libraries
import pandas as pd

# Store the original order of the DataFrame
original_order = fpn.index

# Sort the DataFrame by 'commodity' and 'date' columns
df_sorted = fpn.sort_values(by=['commodity', 'date'])

# Define lag periods
lag_periods = [3, 6, 9, 12, 18, 24]  # in months

# Function to apply lag operation within each commodity group
def lag_prices(group):
    for lag in lag_periods:
        group[f'{lag}m_lag_price'] = group['price'].shift(periods=lag)
    return group

# Apply the lag operation within each commodity group
df_sorted = df_sorted.groupby('commodity').apply(lag_prices)


# Function to add date-related features
def add_date_features(df):
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    return df

# Apply the function to add date-related features
df_sorted = add_date_features(df_sorted)

# Reset the index of df_sorted before assigning it back to fpn
df_sorted = df_sorted.reset_index(drop=True)

# Restore the original order of the DataFrame
fpn = df_sorted

# %%
fpn.sample(20)
# Out:
#             date   admin1        admin2           market   latitude  \
# 50559 2019-08-15     Yobe       Borsari          Bursari  12.496693
# 60653 2017-06-15     Yobe      Damaturu         Damaturu  11.744440
# 27224 2020-08-15   Kaduna          Lere         Saminaka  10.416500
# 50558 2019-08-15      Oyo  Ibadan North           Ibadan   7.401960
# 47451 2019-03-15     Yobe       Borsari          Bursari  12.496693
# 70538 2016-10-15   Kaduna          Giwa             Giwa  11.280160
# 39914 2022-03-15    Borno           Biu              Biu  10.611100
# 67875 2020-01-15    Borno     Maiduguri           Monday  11.834551
# 15111 2017-08-15     Yobe       Borsari          Bursari  12.496693
# 22633 2022-12-15    Borno       Konduga     Abba Gamaram  11.858182
# 10093 2019-03-15    Lagos        Kosofe            Lagos   6.612164
# 66799 2022-01-15    Borno     Maiduguri            Budum  11.849734
# 56383 2016-10-15    Borno     Maiduguri        Maiduguri  11.831100
# 14324 2020-09-15    Borno     Maiduguri           Custom  11.850710
# 34417 2021-12-15     Yobe      Yunusari         Yunusari  13.149834
# 68685 2017-03-15    Borno       Konduga        Baga Road  11.867950
# 111   2017-05-15    Borno     Maiduguri           Custom  11.850710
# 32882 2021-08-15     Yobe       Jakusko          Jakusko  12.201859
# 10144 2019-07-15    Kebbi        Gwandu           Gwandu  12.493820
# 58055 2003-11-15  Katsina      Mai'Adua  Mai Adoua (CBM)  13.180000
#
#        longitude               category             commodity        price  \
# 50559  11.499503     cereals and tubers       Rice (imported)   321.428571
# 60653  11.961110     cereals and tubers       Sorghum (brown)   131.000000
# 27224   8.681380     cereals and tubers         Maize (white)   159.225800
# 50558   3.917310     cereals and tubers       Rice (imported)   321.710000
# 47451  11.499503  vegetables and fruits               Oranges   250.000000
# 70538   7.417860     cereals and tubers                   Yam   185.500000
# 39914  12.195000     cereals and tubers                Millet   188.987100
# 67875  13.152417  vegetables and fruits              Tomatoes   208.800000
# 15111  11.499503    meat, fish and eggs                  Fish   166.666667
# 22633  13.154892        pulses and nuts            Groundnuts   720.000000
# 10093   3.401897        pulses and nuts       Cowpeas (brown)   342.180000
# 66799  13.163442     miscellaneous food                 Sugar   413.846154
# 56383  13.150970     cereals and tubers  Rice (milled, local)   547.500000
# 14324  13.171242    meat, fish and eggs                  Eggs   707.093960
# 34417  11.540236    meat, fish and eggs           Meat (goat)  1300.000000
# 68685  13.123314  vegetables and fruits           Watermelons   226.190476
# 111    13.171242  vegetables and fruits               Bananas   288.461538
# 32882  10.878244    meat, fish and eggs           Meat (beef)  1800.000000
# 10144   4.642270        pulses and nuts       Cowpeas (brown)   132.600000
# 58055   8.230000     cereals and tubers               Sorghum    68.600000
#
#       itemtype  ...  6m_lag_price  9m_lag_price  12m_lag_price  18m_lag_price  \
# 50559    Solid  ...    270.666600    309.350000     293.100000     344.580000
# 60653    Solid  ...    135.700000    153.330000     187.500000     172.360000
# 27224    Solid  ...    178.387100    175.170000     183.741900     168.225800
# 50558    Solid  ...    303.280000    357.190000     295.000000     325.000000
# 47451    Solid  ...    250.000000    125.000000     250.000000     137.500000
# 70538    Solid  ...    117.647059     76.470588     414.500000     592.500000
# 39914    Solid  ...    208.571429    214.285714     214.285714     303.571429
# 67875    Solid  ...    207.800000    300.000000     150.000000     189.400000
# 15111    Solid  ...    566.666667    125.000000     145.833333     166.666667
# 22633    Solid  ...    656.666667    583.333333     745.000000     845.454545
# 10093    Solid  ...    263.450000    208.000000     325.000000     218.750000
# 66799    Solid  ...    500.000000    519.230769     500.000000     576.923077
# 56383    Solid  ...    581.760000    588.480000     604.000000     241.600000
# 14324    Solid  ...    721.476510    704.697987     805.369128     634.228188
# 34417    Solid  ...   1467.000000   2250.000000    2100.000000    1600.000000
# 68685    Solid  ...     95.238095    130.952381     107.142857      83.333333
# 111      Solid  ...    153.846154     76.923077     192.307692     365.384615
# 32882    Solid  ...   1800.000000   1925.000000    1250.000000    1000.000000
# 10144    Solid  ...    195.650000    200.000000     241.160000     191.050000
# 58055    Solid  ...     74.640000     82.290000     107.830000     112.620000
#
#        24m_lag_price     step_1     step_3     step_6 month  year
# 50559     428.571429 2019-08-15 2019-08-15 2019-08-15     8  2019
# 60653     155.000000 2017-06-15 2017-07-15 2017-07-15     6  2017
# 27224     177.393600 2020-08-15 2020-08-15 2020-08-15     8  2020
# 50558     420.000000 2019-08-15 2019-08-15 2019-08-15     8  2019
# 47451     252.750000 2019-03-15 2019-03-15 2019-03-15     3  2019
# 70538     127.500000 2016-10-15 2016-10-15 2016-10-15    10  2016
# 39914     178.140000 2022-03-15 2022-03-15 2022-03-15     3  2022
# 67875     150.000000 2020-01-15 2020-01-15 2020-01-15     1  2020
# 15111     133.333333 2017-08-15 2017-08-15 2017-08-15     8  2017
# 22633     635.833333 2023-01-15 2023-01-15 2023-01-15    12  2022
# 10093     206.730000 2019-03-15 2019-03-15 2019-03-15     3  2019
# 66799     538.461538 2022-01-15 2022-01-15 2022-01-15     1  2022
# 56383     526.800000 2016-10-15 2016-10-15 2016-11-15    10  2016
# 14324     654.362416 2020-09-15 2020-09-15 2020-09-15     9  2020
# 34417    1400.000000 2021-12-15 2022-01-15 2022-01-15    12  2021
# 68685      83.333333 2017-03-15 2017-03-15 2017-03-15     3  2017
# 111       192.307692 2017-05-15 2017-05-15 2017-05-15     5  2017
# 32882    1800.000000 2021-08-15 2021-08-15 2021-09-15     8  2021
# 10144     170.000000 2019-07-15 2019-08-15 2019-08-15     7  2019
# 58055     110.560000 2003-11-15 2003-12-15 2005-01-15    11  2003
#
# [20 rows x 21 columns]

# %%
fpn["commodity"].unique()
# Out:
# array(['Maize', 'Millet', 'Rice (imported)', 'Sorghum', 'Beans (niebe)',
#        'Wheat', 'Maize (white)', 'Sorghum (white)',
#        'Rice (milled, local)', 'Bread', 'Cassava meal (gari, yellow)',
#        'Gari (white)', 'Maize (yellow)', 'Rice (local)',
#        'Sorghum (brown)', 'Yam (Abuja)', 'Oil (palm)', 'Cowpeas (brown)',
#        'Cowpeas (white)', 'Yam', 'Groundnuts (shelled)', 'Maize flour',
#        'Meat (beef)', 'Meat (goat)', 'Milk', 'Oil (vegetable)',
#        'Beans (red)', 'Beans (white)', 'Groundnuts', 'Onions', 'Fish',
#        'Eggs', 'Bananas', 'Oranges', 'Spinach', 'Watermelons', 'Cowpeas',
#        'Tomatoes', 'Salt', 'Sugar'], dtype=object)

# %%
fpn.columns
# Out:
# Index(['date', 'admin1', 'admin2', 'market', 'latitude', 'longitude',
#        'category', 'commodity', 'price', 'itemtype', '6m_lag_price',
#        '12m_lag_price', '24m_lag_price'],
#       dtype='object')

# %%
state_lat_map = fpn.groupby(["admin1"]).agg({"latitude": "mean", "longitude": "mean"}).reset_index()

# %%
dict(state_lat_map)
# Out:
# {'admin1': 0        Abia
#  1     Adamawa
#  2       Borno
#  3       Gombe
#  4      Jigawa
#  5      Kaduna
#  6        Kano
#  7     Katsina
#  8       Kebbi
#  9       Lagos
#  10        Oyo
#  11     Sokoto
#  12       Yobe
#  13    Zamfara
#  Name: admin1, dtype: object,
#  'latitude': 0      5.147640
#  1     10.372833
#  2     11.751709
#  3     10.283330
#  4     12.428109
#  5     10.860932
#  6     12.090120
#  7     12.032723
#  8     12.493820
#  9      6.612164
#  10     7.401960
#  11    13.645000
#  12    12.208103
#  13    12.595190
#  Name: latitude, dtype: float64,
#  'longitude': 0      7.356720
#  1     13.334425
#  2     13.093853
#  3     11.166670
#  4      9.560976
#  5      8.031183
#  6      8.429120
#  7      7.401092
#  8      4.642270
#  9      3.401897
#  10     3.917310
#  11     5.278000
#  12    11.412874
#  13     6.586350
#  Name: longitude, dtype: float64}

# %%
cols_to_drop = ["admin1", "admin2", "market", "itemtype"]
fpn = fpn.drop(cols_to_drop, axis=1)

# %%
fpn
# Out:
#             date   latitude  longitude               category  \
# 0     2002-01-15  13.080000   7.240000     cereals and tubers
# 1     2002-01-15  13.080000   7.240000     cereals and tubers
# 2     2002-01-15  13.080000   7.240000     cereals and tubers
# 3     2002-01-15  13.080000   7.240000     cereals and tubers
# 4     2002-01-15  13.080000   7.240000        pulses and nuts
# ...          ...        ...        ...                    ...
# 73685 2023-12-15  13.062665  11.171371  vegetables and fruits
# 73686 2023-12-15  13.062665  11.171371  vegetables and fruits
# 73687 2023-12-15  13.062665  11.171371  vegetables and fruits
# 73688 2023-12-15  13.062665  11.171371  vegetables and fruits
# 73689 2023-12-15  13.062665  11.171371  vegetables and fruits
#
#              commodity       price  6m_lag_price  12m_lag_price  24m_lag_price
# 0                Maize  175.920000           NaN            NaN            NaN
# 1               Millet  150.180000           NaN            NaN            NaN
# 2      Rice (imported)  358.700000           NaN            NaN            NaN
# 3              Sorghum  155.610000           NaN            NaN            NaN
# 4        Beans (niebe)  196.870000           NaN            NaN            NaN
# ...                ...         ...           ...            ...            ...
# 73685           Onions  400.000000    825.000000     397.920000    1000.000000
# 73686          Oranges  500.000000    500.000000     492.200000     462.500000
# 73687          Spinach  166.666667    166.666667     166.666667     283.333333
# 73688         Tomatoes  400.000000    400.000000     329.160000     370.000000
# 73689      Watermelons  190.476190    186.509524     137.895238     333.333333
#
# [70824 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode category column
fpn['category'] = label_encoder.fit_transform(fpn['category'])

# Encode commodity column
fpn['commodity'] = label_encoder.fit_transform(fpn['commodity'])

fpn
# Out:
#             date   latitude  longitude  category  commodity       price  \
# 0     2002-01-15  13.080000   7.240000         0         14  175.920000
# 1     2002-01-15  13.080000   7.240000         0         21  150.180000
# 2     2002-01-15  13.080000   7.240000         0         26  358.700000
# 3     2002-01-15  13.080000   7.240000         0         30  155.610000
# 4     2002-01-15  13.080000   7.240000         5          1  196.870000
# ...          ...        ...        ...       ...        ...         ...
# 73685 2023-12-15  13.062665  11.171371         6         24  400.000000
# 73686 2023-12-15  13.062665  11.171371         6         25  500.000000
# 73687 2023-12-15  13.062665  11.171371         6         33  166.666667
# 73688 2023-12-15  13.062665  11.171371         6         35  400.000000
# 73689 2023-12-15  13.062665  11.171371         6         36  190.476190
#
#        6m_lag_price  12m_lag_price  24m_lag_price
# 0               NaN            NaN            NaN
# 1               NaN            NaN            NaN
# 2               NaN            NaN            NaN
# 3               NaN            NaN            NaN
# 4               NaN            NaN            NaN
# ...             ...            ...            ...
# 73685    825.000000     397.920000    1000.000000
# 73686    500.000000     492.200000     462.500000
# 73687    166.666667     166.666667     283.333333
# 73688    400.000000     329.160000     370.000000
# 73689    186.509524     137.895238     333.333333
#
# [70824 rows x 9 columns]

# %%
fpn.isna().sum()
# Out:
# date               0
# latitude           0
# longitude          0
# category           0
# commodity          0
# price              0
# 6m_lag_price     240
# 12m_lag_price    480
# 24m_lag_price    960
# dtype: int64

# %%
fpn = fpn.dropna()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# Step 1: Split the data into training and validation sets
train_data = fpn[fpn['date'] < '2023-01-01']  # Training data
valid_data = fpn[fpn['date'] >= '2023-01-01']  # Validation data

# Step 3: Train a random forest regression model
features = ['latitude', 'longitude', 'category', 'commodity', '6m_lag_price', '12m_lag_price', '24m_lag_price'] 
X_train = train_data[features]
y_train = train_data['price']
model = RandomForestRegressor()
model.fit(X_train, y_train)

# Step 4: Predict the prices for the validation set
X_valid = valid_data[features]
y_valid = valid_data['price']
y_pred = model.predict(X_valid)

# Step 5: Evaluate the model's performance using RMSE
rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
print('RMSE:', rmse)
# Out:
# RMSE: 9614.4199329734

# %%
# Create a DataFrame with actual and predicted prices
comparison_df = pd.DataFrame({'Date': valid_data['date'],
                              'Actual Price': y_valid,
                              'Predicted Price': y_pred})

print(comparison_df)
# Out:
#             Date  Actual Price  Predicted Price
# 50380 2023-02-15    287.692308       201.962435
# 50381 2023-02-15    290.000000       245.715756
# 50382 2023-02-15    690.000000       588.652449
# 50383 2023-02-15    290.000000       278.536698
# 50384 2023-02-15    235.294118       387.352086
# ...          ...           ...              ...
# 73685 2023-12-15    400.000000       585.041171
# 73686 2023-12-15    500.000000       475.017371
# 73687 2023-12-15    166.666667       111.681408
# 73688 2023-12-15    400.000000       402.066937
# 73689 2023-12-15    190.476190       134.385772
#
# [8739 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted prices
plt.figure(figsize=(10, 6))
plt.plot(valid_data['date'], y_valid, label='Actual Price', color='blue')
plt.plot(valid_data['date'], y_pred, label='Predicted Price', color='red')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual vs Predicted Prices')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Plot actual vs predicted prices
plt.figure(figsize=(10, 6))
plt.plot(valid_data['date'], y_valid, label='Actual Price', color='blue', linestyle='-')
plt.plot(valid_data['date'], y_pred, label='Predicted Price', color='red', linestyle='--')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual vs Predicted Prices')
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import numpy as np

# Step 1: Split the data into training and validation sets
train_data = fpn[fpn['date'] < '2023-01-01']  # Training data
valid_data = fpn[fpn['date'] >= '2023-01-01']  # Validation data

# Step 2: Fill missing values in lag columns using backward fill based on commodity
lag_columns = ['6m_lag_price', '12m_lag_price', '24m_lag_price']
for col in lag_columns:
    valid_data[col] = valid_data.groupby('commodity')[col].fillna(method='bfill')
# Out:
# C:\Users\Nnamdi\AppData\Local\Temp\ipykernel_32524\1711806997.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_data[col] = valid_data.groupby('commodity')[col].fillna(method='bfill')
# C:\Users\Nnamdi\AppData\Local\Temp\ipykernel_32524\1711806997.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_data[col] = valid_data.groupby('commodity')[col].fillna(method='bfill')
# C:\Users\Nnamdi\AppData\Local\Temp\ipykernel_32524\1711806997.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid_data[col] = valid_data.groupby('commodity')[col].fillna(method='bfill')

# %%
# Step 1: Split the data into training and validation sets
train_data = fpn[fpn['date'] < '2023-01-01']  # Training data
valid_data = fpn[fpn['date'] >= '2023-01-01']  # Validation data

# %%
valid_data
# Out:
#             date   latitude  longitude               category     commodity  \
# 50380 2023-02-15  11.858182  13.154892     cereals and tubers   Maize flour
# 50381 2023-02-15  11.858182  13.154892     cereals and tubers        Millet
# 50382 2023-02-15  11.858182  13.154892     cereals and tubers  Rice (local)
# 50383 2023-02-15  11.858182  13.154892     cereals and tubers       Sorghum
# 50384 2023-02-15  11.858182  13.154892     cereals and tubers           Yam
# ...          ...        ...        ...                    ...           ...
# 73685 2023-12-15  13.062665  11.171371  vegetables and fruits        Onions
# 73686 2023-12-15  13.062665  11.171371  vegetables and fruits       Oranges
# 73687 2023-12-15  13.062665  11.171371  vegetables and fruits       Spinach
# 73688 2023-12-15  13.062665  11.171371  vegetables and fruits      Tomatoes
# 73689 2023-12-15  13.062665  11.171371  vegetables and fruits   Watermelons
#
#             price  6m_lag_price  12m_lag_price  24m_lag_price
# 50380  287.692308    237.332000     360.000000     280.000000
# 50381  290.000000    214.784000     219.332000     257.200000
# 50382  690.000000    480.000000     620.000000     599.400000
# 50383  290.000000    202.000000     360.000000     308.000000
# 50384  235.294118    332.172000     382.668000     340.000000
# ...           ...           ...            ...            ...
# 73685  400.000000    825.000000     397.920000    1000.000000
# 73686  500.000000    500.000000     492.200000     462.500000
# 73687  166.666667    166.666667     166.666667     283.333333
# 73688  400.000000    400.000000     329.160000     370.000000
# 73689  190.476190    186.509524     137.895238     333.333333
#
# [8739 rows x 9 columns]

# %%
valid_data
# Out:
#             date   latitude  longitude               category     commodity  \
# 50380 2023-02-15  11.858182  13.154892     cereals and tubers   Maize flour
# 50381 2023-02-15  11.858182  13.154892     cereals and tubers        Millet
# 50382 2023-02-15  11.858182  13.154892     cereals and tubers  Rice (local)
# 50383 2023-02-15  11.858182  13.154892     cereals and tubers       Sorghum
# 50384 2023-02-15  11.858182  13.154892     cereals and tubers           Yam
# ...          ...        ...        ...                    ...           ...
# 73685 2023-12-15  13.062665  11.171371  vegetables and fruits        Onions
# 73686 2023-12-15  13.062665  11.171371  vegetables and fruits       Oranges
# 73687 2023-12-15  13.062665  11.171371  vegetables and fruits       Spinach
# 73688 2023-12-15  13.062665  11.171371  vegetables and fruits      Tomatoes
# 73689 2023-12-15  13.062665  11.171371  vegetables and fruits   Watermelons
#
#             price  6m_lag_price  12m_lag_price  24m_lag_price
# 50380  287.692308    237.332000     360.000000     280.000000
# 50381  290.000000    214.784000     219.332000     257.200000
# 50382  690.000000    480.000000     620.000000     599.400000
# 50383  290.000000    202.000000     360.000000     308.000000
# 50384  235.294118    332.172000     382.668000     340.000000
# ...           ...           ...            ...            ...
# 73685  400.000000    825.000000     397.920000    1000.000000
# 73686  500.000000    500.000000     492.200000     462.500000
# 73687  166.666667    166.666667     166.666667     283.333333
# 73688  400.000000    400.000000     329.160000     370.000000
# 73689  190.476190    186.509524     137.895238     333.333333
#
# [8739 rows x 9 columns]
