# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from datetime import datetime, timedelta
from sklearn.linear_model import LinearRegression

# Load data
fpn = pd.read_csv("raw_data.csv")  # Load your data here

# Function to create features
def create_features(df):
    df = df.copy()
    df['date'] = pd.to_datetime(df['date'])
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.isocalendar().week
    df.set_index('date',inplace =True)
    return df

# %%
fpn
# Out:
#              date   admin1    admin2       market   latitude  longitude  \
# 0      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 1      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 2      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 3      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# 4      2002-01-15  Katsina     Jibia  Jibia (CBM)  13.080000   7.240000
# ...           ...      ...       ...          ...        ...        ...
# 73685  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73686  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73687  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73688  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
# 73689  2023-12-15     Yobe  Yusufari     Yusufari  13.062665  11.171371
#
#                     category        commodity       price
# 0         cereals and tubers            Maize  175.920000
# 1         cereals and tubers           Millet  150.180000
# 2         cereals and tubers  Rice (imported)  358.700000
# 3         cereals and tubers          Sorghum  155.610000
# 4            pulses and nuts    Beans (niebe)  196.870000
# ...                      ...              ...         ...
# 73685  vegetables and fruits           Onions  400.000000
# 73686  vegetables and fruits          Oranges  500.000000
# 73687  vegetables and fruits          Spinach  166.666667
# 73688  vegetables and fruits         Tomatoes  400.000000
# 73689  vegetables and fruits      Watermelons  190.476190
#
# [73690 rows x 9 columns]

# %%
grouped = fpn.groupby(['date', 'commodity'])
print(grouped)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x1527eac90>

# %%
df = pd.DataFrame(grouped['price'].mean())
df
# Out:
#                                   price
# date       commodity
# 2002-01-15 Beans (niebe)     217.970000
#            Maize             164.635000
#            Millet            148.565000
#            Rice (imported)   348.145000
#            Sorghum           148.555000
# ...                                 ...
# 2023-12-15 Spinach           331.238272
#            Sugar            1567.442222
#            Tomatoes          300.160000
#            Watermelons       203.604938
#            Yam               675.198222
#
# [4560 rows x 1 columns]

# %%
df = df.sort_values(by=['commodity','date']).reset_index()
df
# Out:
#             date    commodity       price
# 0     2013-12-15      Bananas  230.769231
# 1     2014-01-15      Bananas  230.769231
# 2     2015-01-15      Bananas  269.230769
# 3     2016-01-15      Bananas  269.230769
# 4     2016-08-15      Bananas  197.871795
# ...          ...          ...         ...
# 4555  2022-06-15  Yam (Abuja)  346.213330
# 4556  2022-07-15  Yam (Abuja)  417.420000
# 4557  2022-11-15  Yam (Abuja)  163.915000
# 4558  2022-12-15  Yam (Abuja)  172.811770
# 4559  2023-01-15  Yam (Abuja)  183.765000
#
# [4560 rows x 3 columns]

# %%
# df['date'] = pd.to_datetime(pd.to_datetime(df['date']).apply(lambda x: x.strftime('%Y-%m')))
# df

# %%
rice = df[df['commodity'] == 'Rice (imported)']
rice
# Out:
#             date        commodity        price
# 2952  2002-01-15  Rice (imported)   348.145000
# 2953  2002-02-15  Rice (imported)   381.970000
# 2954  2002-03-15  Rice (imported)   353.235000
# 2955  2002-04-15  Rice (imported)   344.430000
# 2956  2002-05-15  Rice (imported)   351.560000
# ...          ...              ...          ...
# 3181  2023-08-15  Rice (imported)  1075.158500
# 3182  2023-09-15  Rice (imported)  1142.956615
# 3183  2023-10-15  Rice (imported)  1160.833857
# 3184  2023-11-15  Rice (imported)  1212.097857
# 3185  2023-12-15  Rice (imported)  1300.080870
#
# [234 rows x 3 columns]

# %%
rice['date'] = pd.to_datetime(rice['date'])
rice.set_index('date', inplace=True)
rice.index = rice.index.to_period('D')
# Out:
# /var/folders/fz/h0vksxt90g7g6hs6xqx9rbdc0000gp/T/ipykernel_42025/4261929225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rice['date'] = pd.to_datetime(rice['date'])

# %%
rice
# Out:
#                   commodity        price
# date
# 2002-01-15  Rice (imported)   348.145000
# 2002-02-15  Rice (imported)   381.970000
# 2002-03-15  Rice (imported)   353.235000
# 2002-04-15  Rice (imported)   344.430000
# 2002-05-15  Rice (imported)   351.560000
# ...                     ...          ...
# 2023-08-15  Rice (imported)  1075.158500
# 2023-09-15  Rice (imported)  1142.956615
# 2023-10-15  Rice (imported)  1160.833857
# 2023-11-15  Rice (imported)  1212.097857
# 2023-12-15  Rice (imported)  1300.080870
#
# [234 rows x 2 columns]

# %%
# Time-step feature to determine time-dependence

# %%
import numpy as np

rice['time'] = np.arange(len(rice.index))
# Out:
# /var/folders/fz/h0vksxt90g7g6hs6xqx9rbdc0000gp/T/ipykernel_42025/646538317.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rice['time'] = np.arange(len(rice.index))

# %%
rice
# Out:
#                   commodity        price  time
# date
# 2002-01-15  Rice (imported)   348.145000     0
# 2002-02-15  Rice (imported)   381.970000     1
# 2002-03-15  Rice (imported)   353.235000     2
# 2002-04-15  Rice (imported)   344.430000     3
# 2002-05-15  Rice (imported)   351.560000     4
# ...                     ...          ...   ...
# 2023-08-15  Rice (imported)  1075.158500   229
# 2023-09-15  Rice (imported)  1142.956615   230
# 2023-10-15  Rice (imported)  1160.833857   231
# 2023-11-15  Rice (imported)  1212.097857   232
# 2023-12-15  Rice (imported)  1300.080870   233
#
# [234 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split as tts

# %%
X = rice.loc[:, ['time']]
y = rice.loc[:, 'price']

# %%
# X_train, X_test, y_train, y_test = tts(X, y, random_state=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the white grid style using Seaborn's dedicated function
sns.set_style("whitegrid")

# Configure plot aesthetics using plt.rc() for finer control
plt.rc('figure',
       autolayout=True,
       figsize=(11, 4),  # Adjust figure size as needed
       titlesize=18,
       titleweight='bold')

plt.rc('axes',
       labelweight='bold',
       labelsize='large',
       titleweight='bold',
       titlesize=16,
       titlepad=10)

# %%
import seaborn as sns
# %matplotlib inline

fig, ax = plt.subplots()
ax.plot('time', 'price', data=rice)
ax = sns.regplot(x='time', y='price', data=rice, ci=None, scatter_kws=dict(color='red'))
# ax2 = sns.regplot(x='time', y='price', data=bananas, ci=90, scatter_kws=dict(color='blue'))
ax.set_title('Time-Step Plot for Rice')
plt.show()

# %%
X = rice.loc[:, ['time']]
y = rice.loc[:, 'price']
model1 = LinearRegression()
model1.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = pd.Series(model1.predict(X), index=X.index)

# %%
ax = y.plot( y='price', alpha=0.5)
ax = y_pred.plot(ax=ax, linewidth=3)
ax.set_title('Time Plot For Rice');

# %%
df1
# Out:
#                   commodity        price  time
# date
# 2002-01-15  Rice (imported)   348.145000     0
# 2002-02-15  Rice (imported)   381.970000     1
# 2002-03-15  Rice (imported)   353.235000     2
# 2002-04-15  Rice (imported)   344.430000     3
# 2002-05-15  Rice (imported)   351.560000     4
# ...                     ...          ...   ...
# 2023-08-15  Rice (imported)  1075.158500   229
# 2023-09-15  Rice (imported)  1142.956615   230
# 2023-10-15  Rice (imported)  1160.833857   231
# 2023-11-15  Rice (imported)  1212.097857   232
# 2023-12-15  Rice (imported)  1300.080870   233
#
# [234 rows x 3 columns]

# %%
# trends

# %%
moving_average = rice['price'].rolling(window=30, center=True, min_periods=15).mean()
ax = rice.plot(style=".", color="0.5")
moving_average.plot(ax=ax, linewidth=3, title="Imported Rice Price - 365-Day Moving Average", legend=False)
# Out:
# <Axes: title={'center': 'Imported Rice Price - 365-Day Moving Average'}, xlabel='date'>

# %%
from statsmodels.tsa.deterministic import DeterministicProcess

df1 = rice.copy()

dp = DeterministicProcess(
    index=df1.index,  # dates from the training data
    constant=True,       # dummy feature for the bias (y_intercept)
    order=1,             # the time dummy (trend)
    drop=True,           # drop terms if necessary to avoid collinearity
)
# `in_sample` creates features for the dates given in the `index` argument
X = dp.in_sample()

X.head()
# Out:
#             const  trend
# date
# 2002-01-15    1.0    1.0
# 2002-02-15    1.0    2.0
# 2002-03-15    1.0    3.0
# 2002-04-15    1.0    4.0
# 2002-05-15    1.0    5.0

# %%
X
# Out:
#             const  trend
# date
# 2002-01-15    1.0    1.0
# 2002-02-15    1.0    2.0
# 2002-03-15    1.0    3.0
# 2002-04-15    1.0    4.0
# 2002-05-15    1.0    5.0
# ...           ...    ...
# 2023-08-15    1.0  230.0
# 2023-09-15    1.0  231.0
# 2023-10-15    1.0  232.0
# 2023-11-15    1.0  233.0
# 2023-12-15    1.0  234.0
#
# [234 rows x 2 columns]

# %%
X.index = X.index.to_timestamp(freq='M')

# %%
from sklearn.linear_model import LinearRegression

y = df1["price"]  # the target

# The intercept is the same as the `const` feature from
# DeterministicProcess. LinearRegression behaves badly with duplicated
# features, so we need to be sure to exclude it here.
model = LinearRegression(fit_intercept=False)
model.fit(X, y)

y_pred = pd.Series(model.predict(X), index=X.index)

# %%
X.index
# Out:
# PeriodIndex(['2002-01-15', '2002-02-15', '2002-03-15', '2002-04-15',
#              '2002-05-15', '2002-06-15', '2002-07-15', '2002-08-15',
#              '2002-09-15', '2002-10-15',
#              ...
#              '2023-03-15', '2023-04-15', '2023-05-15', '2023-06-15',
#              '2023-07-15', '2023-08-15', '2023-09-15', '2023-10-15',
#              '2023-11-15', '2023-12-15'],
#             dtype='period[D]', name='date', length=234)

# %%
X = dp.out_of_sample(steps=30)

y_fore = pd.Series(model.predict(X), index=X.index)

y_fore
# Out:
# 2023-12-16    600.493618
# 2023-12-17    601.980675
# 2023-12-18    603.467731
# 2023-12-19    604.954788
# 2023-12-20    606.441845
# 2023-12-21    607.928901
# 2023-12-22    609.415958
# 2023-12-23    610.903015
# 2023-12-24    612.390071
# 2023-12-25    613.877128
# 2023-12-26    615.364185
# 2023-12-27    616.851242
# 2023-12-28    618.338298
# 2023-12-29    619.825355
# 2023-12-30    621.312412
# 2023-12-31    622.799468
# 2024-01-01    624.286525
# 2024-01-02    625.773582
# 2024-01-03    627.260638
# 2024-01-04    628.747695
# 2024-01-05    630.234752
# 2024-01-06    631.721808
# 2024-01-07    633.208865
# 2024-01-08    634.695922
# 2024-01-09    636.182978
# 2024-01-10    637.670035
# 2024-01-11    639.157092
# 2024-01-12    640.644148
# 2024-01-13    642.131205
# 2024-01-14    643.618262
# Freq: D, dtype: float64

# %%
ax = df1.plot(title="Imported Rice Price - Linear Trend Forecast", y='price')
ax = y_pred.plot(ax=ax, linewidth=3, label="Trend")
ax = y_fore.plot(ax=ax, linewidth=3, label="Trend Forecast", color="C3")
_ = ax.legend()
plt.show()
